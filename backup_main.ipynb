# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from dataevaluator import DataEvaluator
from helper import run_model_evaluation
from models.knn import KNN
from models.mlp import MLP
from models.logistic import LogReg

# %%
data = DataEvaluator('dataset')
X_train, y_train, X_test, y_test = data.get_data()
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
clothing_types = data.clothing_types
# Out:
# (60000, 784) (60000,) (10000, 784) (10000,)

# %%
l = LogReg()
k = KNN()
f = MLP()

# %% [markdown]
# ## Data Exploration

# %%
data.plot_clothing_distribution()
# Out:
# (label
#  0    6000
#  1    6000
#  2    6000
#  3    6000
#  4    6000
#  5    6000
#  6    6000
#  7    6000
#  8    6000
#  9    6000
#  Name: count, dtype: int64,
#  label
#  0    1000
#  1    1000
#  2    1000
#  3    1000
#  4    1000
#  5    1000
#  6    1000
#  7    1000
#  8    1000
#  9    1000
#  Name: count, dtype: int64)

# %% [markdown]
# # Training Models

# %%
le, levals, ltime, letime = run_model_evaluation(l, "Logistic Regression", X_train, y_train, X_test, y_test, color="YlGnBu")
print(f"Training time for Logistic Regression: {ltime:.2f} seconds")
print(f"Evaluation time for Logistic Regression: {letime:.2f} seconds")
# Out:
# c:\Users\shubh\.conda\envs\cs178thing\lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 1000 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=1000).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Logistic Regression Accuracy: 0.8339  Precision: 0.8325466974881736  Recall: 0.8339  F1 Score: 0.8327723903439768
# Logistic Regression class 0 AUC: 0.9803399999999999
# Logistic Regression class 1 AUC: 0.9980123333333334
# Logistic Regression class 2 AUC: 0.9691068888888889
# Logistic Regression class 3 AUC: 0.9855804444444444
# Logistic Regression class 4 AUC: 0.9721720000000001
# Logistic Regression class 5 AUC: 0.9957022222222223
# Logistic Regression class 6 AUC: 0.9310339999999999
# Logistic Regression class 7 AUC: 0.9966284444444445
# Logistic Regression class 8 AUC: 0.9922935555555555
# Logistic Regression class 9 AUC: 0.9973631111111112
# Logistic Regression pair 0 vs 7 AUC: 0.99997
# Logistic Regression pair 0 vs 9 AUC: 0.999937
# Logistic Regression pair 2 vs 9 AUC: 0.999989
# Logistic Regression pair 0 vs 6 AUC: 0.819446
# Logistic Regression pair 2 vs 4 AUC: 0.8996000000000001
# Logistic Regression pair 2 vs 6 AUC: 0.829936
# Logistic Regression pair 4 vs 6 AUC: 0.839463
# Logistic Regression pair 5 vs 7 AUC: 0.985845
# Training time for Logistic Regression: 172.45 seconds
# Evaluation time for Logistic Regression: 2.79 seconds

# %%
ke, kevals, kfit_time, k_eval_time = run_model_evaluation(k, "kNN", X_train, y_train, X_test, y_test, color="magma")
print(f"Training time for kNN: {kfit_time:.2f} seconds")
print(f"Evaluation time for kNN: {k_eval_time:.2f} seconds")
# Out:
# kNN Accuracy: 0.8541  Precision: 0.8575414622679564  Recall: 0.8541  F1 Score: 0.8539002124666113
# kNN class 0 AUC: 0.9542606111111112
# kNN class 1 AUC: 0.9913077222222222
# kNN class 2 AUC: 0.9405953888888889
# kNN class 3 AUC: 0.9624106111111111
# kNN class 4 AUC: 0.9356387777777779
# kNN class 5 AUC: 0.9592309444444445
# kNN class 6 AUC: 0.8745229999999999
# kNN class 7 AUC: 0.9901653888888889
# kNN class 8 AUC: 0.9849315555555556
# kNN class 9 AUC: 0.9906477777777778
# kNN pair 0 vs 9 AUC: 0.994
# kNN pair 1 vs 5 AUC: 0.9595
# kNN pair 1 vs 7 AUC: 0.994
# kNN pair 0 vs 6 AUC: 0.8115815000000001
# kNN pair 2 vs 4 AUC: 0.8986250000000001
# kNN pair 2 vs 6 AUC: 0.8368019999999999
# kNN pair 4 vs 6 AUC: 0.830953
# kNN pair 5 vs 7 AUC: 0.9709809999999999
# Training time for kNN: 0.01 seconds
# Evaluation time for kNN: 52.35 seconds

# %%
fe, fevals, ftime, fetime = run_model_evaluation(f, "MLP", X_train, y_train, X_test, y_test, color="viridis")
print(f"Training time for MLP: {ftime:.2f} seconds")
print(f"Evaluation time for MLP: {fetime:.2f} seconds")

plt.plot(f.classifier.loss_curve_)
plt.xlabel('Iterations')
plt.ylabel('Loss')
plt.title('MLP Loss Curve')
plt.savefig('figures/MLP_loss_curve.png')
plt.show()
# Out:
# MLP Accuracy: 0.8441  Precision: 0.8507877018370523  Recall: 0.8441  F1 Score: 0.8449682353745277
# MLP class 0 AUC: 0.9804733888888889
# MLP class 1 AUC: 0.9966169444444444
# MLP class 2 AUC: 0.9686299444444446
# MLP class 3 AUC: 0.9861380555555554
# MLP class 4 AUC: 0.9751347777777777
# MLP class 5 AUC: 0.996887888888889
# MLP class 6 AUC: 0.9438203888888889
# MLP class 7 AUC: 0.9974695555555556
# MLP class 8 AUC: 0.9963578333333334
# MLP class 9 AUC: 0.9978122222222222
# MLP pair 0 vs 7 AUC: 0.999628
# MLP pair 0 vs 9 AUC: 0.999414
# MLP pair 2 vs 5 AUC: 0.995198
# MLP pair 0 vs 6 AUC: 0.8464985
# MLP pair 2 vs 4 AUC: 0.881724
# MLP pair 2 vs 6 AUC: 0.8260925
# MLP pair 4 vs 6 AUC: 0.885494
# MLP pair 0 vs 3 AUC: 0.9700265
# Training time for MLP: 117.59 seconds
# Evaluation time for MLP: 3.31 seconds

# %%
models = ["Logistic Regression", "kNN", "MLP"]
catcounts = {"Logistic Regression": np.diag(levals.cm) , "kNN": np.diag(kevals.cm) , "MLP": np.diag(fevals.cm)}
cataccs = {model: counts/1000 for model, counts in catcounts.items()}

# Graph the numeric accuracies
x = np.arange(len(clothing_types))
width = 0.275
[plt.bar(x - width + i*width, cataccs[model], width, label=model) for i, model in enumerate(models)]
plt.xlabel('Clothing Category')
plt.ylabel('Number of Correct Predictions')
plt.title('Accuracy of Models by Clothing Category')
plt.xticks(x, [clothing_types[i] for i in clothing_types.keys()], rotation=45)
plt.legend()
plt.tight_layout()
plt.savefig('figures/model_category_accuracies.png')
plt.show()

# %%
[print(f"{model} Category Accuracy: {cataccs[model]}") for model in models]
totaccs = {model: np.round(np.sum(cataccs[model])/10, 4) for model in models}
print("Sorted by Overall Accuracy:", sorted([{"Logistic Regression": totaccs["Logistic Regression"]}, {"kNN": totaccs["kNN"]}, {"MLP": totaccs["MLP"]}], key=lambda x: list(x.values())[0], reverse=True))
# Out:
# Logistic Regression Category Accuracy: [0.792 0.956 0.731 0.84  0.77  0.893 0.554 0.935 0.927 0.941]
# kNN Category Accuracy: [0.853 0.971 0.812 0.855 0.743 0.835 0.595 0.952 0.952 0.973]
# MLP Category Accuracy: [0.696 0.948 0.627 0.854 0.826 0.94  0.687 0.952 0.957 0.954]
# Sorted by Overall Accuracy: [{'kNN': np.float64(0.8541)}, {'MLP': np.float64(0.8441)}, {'Logistic Regression': np.float64(0.8339)}]

# %%
performance_by_category = pd.DataFrame({model: cataccs[model] for model in models}, index=[clothing_types[i] for i in clothing_types.keys()])
print("Performance by Category:", performance_by_category, sep="\n")
print("\nSorted by Category Accuracy:")
for category in performance_by_category.index:
    sorted_models = performance_by_category.loc[category].sort_values(ascending=False)
    print(f"Category {category}: {sorted_models.to_dict()}")
# Out:
# Performance by Category:
#              Logistic Regression    kNN    MLP
# T-shirt/top                0.792  0.853  0.696
# Trouser                    0.956  0.971  0.948
# Pullover                   0.731  0.812  0.627
# Dress                      0.840  0.855  0.854
# Coat                       0.770  0.743  0.826
# Sandal                     0.893  0.835  0.940
# Shirt                      0.554  0.595  0.687
# Sneaker                    0.935  0.952  0.952
# Bag                        0.927  0.952  0.957
# Ankle boot                 0.941  0.973  0.954
#
# Sorted by Category Accuracy:
# Category T-shirt/top: {'kNN': 0.853, 'Logistic Regression': 0.792, 'MLP': 0.696}
# Category Trouser: {'kNN': 0.971, 'Logistic Regression': 0.956, 'MLP': 0.948}
# Category Pullover: {'kNN': 0.812, 'Logistic Regression': 0.731, 'MLP': 0.627}
# Category Dress: {'kNN': 0.855, 'MLP': 0.854, 'Logistic Regression': 0.84}
# Category Coat: {'MLP': 0.826, 'Logistic Regression': 0.77, 'kNN': 0.743}
# Category Sandal: {'MLP': 0.94, 'Logistic Regression': 0.893, 'kNN': 0.835}
# Category Shirt: {'MLP': 0.687, 'kNN': 0.595, 'Logistic Regression': 0.554}
# Category Sneaker: {'kNN': 0.952, 'MLP': 0.952, 'Logistic Regression': 0.935}
# Category Bag: {'MLP': 0.957, 'kNN': 0.952, 'Logistic Regression': 0.927}
# Category Ankle boot: {'kNN': 0.973, 'MLP': 0.954, 'Logistic Regression': 0.941}

# %%
best_model_by_category = performance_by_category.idxmax(axis=1)
print(f"Best model by category:", best_model_by_category, sep="\n")
print("\nImportant Note: Sneakers category was actually a tie, but marked as a kNN win.")
print("Regardless, kNN still wins 5 of 9 categories.\n")
print(f"Model best performace counts by category: \n{best_model_by_category.value_counts()}")
print(f"Model with most category wins: {best_model_by_category.value_counts().idxmax()}")
# Out:
# Best model by category:
# T-shirt/top    kNN
# Trouser        kNN
# Pullover       kNN
# Dress          kNN
# Coat           MLP
# Sandal         MLP
# Shirt          MLP
# Sneaker        kNN
# Bag            MLP
# Ankle boot     kNN
# dtype: object
#
# Important Note: Sneakers category was actually a tie, but marked as a kNN win.
# Regardless, kNN still wins 5 of 9 categories.
#
# Model best performace counts by category:
# kNN    6
# MLP    4
# Name: count, dtype: int64
# Model with most category wins: kNN
